# %%
import pandas as pd
import csv
import torch
import torch.nn.functional as F
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from IPython.core.display import HTML
from matplotlib import animation
from matplotlib.colors import ListedColormap
import ANNlinear as AL

# %% [markdown]
# <font color=black size=7 face="Times New Roman"> Backward Propogation </font>

# %% [markdown]
# <font color=black size=7 face="Times New Roman"> One Hidden Layer in forward</font>

# %%
n_train = 300
n_hidden_layer = [10]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L1(
#   (hidden_layer): Linear(in_features=2, out_features=10, bias=True)
#   (predict_layer): Linear(in_features=10, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 76.45045
#             0         1         2         3         4         5
# 0    0.380184  0.820934  0.955134  0.656701  0.935257  0.964549
# 1    0.380166  0.820787  0.954751  0.656593  0.935188  0.964300
# 2    0.381734  0.833598  0.988110  0.666019  0.941198  0.985966
# 3    0.380069  0.820001  0.952703  0.656015  0.934819  0.962971
# 4    0.380273  0.821667  0.957043  0.657241  0.935601  0.965789
# ..        ...       ...       ...       ...       ...       ...
# 191  0.420702  0.508739  0.341893  0.550759  0.896824  0.066999
# 192  0.482785  0.662427  0.860647  0.769665  1.001622  0.010960
# 193  0.445114  0.709169  0.853704  0.656368  1.020051  0.530781
# 194  0.474573  0.618481  0.737235  0.725172  0.982556 -0.027067
# ...

# %%
n_train = 300
n_hidden_layer = [20]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L1(
#   (hidden_layer): Linear(in_features=2, out_features=20, bias=True)
#   (predict_layer): Linear(in_features=20, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 86.31499
#             0         1         2         3         4         5
# 0    0.380538  0.664058  0.928293  0.854562  1.001586  0.969857
# 1    0.378505  0.655010  0.917506  0.859533  0.997406  0.954980
# 2    0.059133  1.301191  1.385563  1.246680 -0.170322 -0.120850
# 3    0.378496  0.654969  0.917458  0.859556  0.997388  0.954914
# 4    0.387660  0.695765  0.966088  0.837143  1.016232  1.021986
# ..        ...       ...       ...       ...       ...       ...
# 191  0.449462  0.618568  0.878152  0.815366  0.978130  0.094728
# 192  0.442878  0.567778  0.824469  0.838766  0.971455  0.039240
# 193  0.450585  0.628587  0.882080  0.803792  0.979760  0.111565
# 194  0.343784  0.613342  0.456040  0.575281  0.748932  0.228738
# ...

# %%
n_train = 300
n_hidden_layer = [30]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L1(
#   (hidden_layer): Linear(in_features=2, out_features=30, bias=True)
#   (predict_layer): Linear(in_features=30, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 86.40765
#             0         1         2         3         4         5
# 0    0.400329  0.686195  0.935516  0.828953  0.973248  1.012352
# 1    0.399861  0.680787  0.930543  0.829982  0.972708  1.011939
# 2    0.291443  0.459349  0.177410  0.061078  1.000181  1.007624
# 3    0.405092  0.741272  0.986171  0.818480  0.978751  1.016561
# 4    0.400301  0.685874  0.935221  0.829014  0.973216  1.012328
# ..        ...       ...       ...       ...       ...       ...
# 191  0.422463  0.566346  0.626313  0.716267  0.886051 -0.060541
# 192  0.454260  0.564490  0.751903  0.804560  0.937856 -0.027050
# 193  0.359280  0.605121  0.480201  0.649647  0.769997  0.018753
# 194  0.395162  0.536736  0.590039  0.569503  0.967772  0.457880
# ...

# %%
n_train = 300
n_hidden_layer = [40]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L1(
#   (hidden_layer): Linear(in_features=2, out_features=40, bias=True)
#   (predict_layer): Linear(in_features=40, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 75.40483
#             0         1         2         3         4         5
# 0    0.430181  0.698515  0.855790  0.845303  0.966364  0.961788
# 1    0.429126  0.698258  0.853057  0.844160  0.964235  0.959287
# 2    0.447993  0.771237  0.926407  0.799402  0.993088  0.997311
# 3    0.446066  0.761682  0.918163  0.805977  0.990425  0.993633
# 4    0.448132  0.771926  0.927002  0.798928  0.993280  0.997576
# ..        ...       ...       ...       ...       ...       ...
# 191  0.458354  0.938386  1.024745  0.427894  1.012575  0.692644
# 192  0.460632  0.933657  1.024226  0.440357  1.012111  0.663911
# 193  0.497255  0.702812  0.902222  0.794033  0.993486 -0.003241
# 194  0.485220  0.607172  0.816409  0.847624  0.987236 -0.011319
# ...

# %%
n_train = 300
n_hidden_layer = [10, 10]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L2(
#   (hidden_layer1): Linear(in_features=2, out_features=10, bias=True)
#   (hidden_layer2): Linear(in_features=10, out_features=10, bias=True)
#   (predict_layer): Linear(in_features=10, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 94.47161
#             0         1         2         3         4         5
# 0    0.440393  0.802405  0.966853  0.624839  1.046827  0.974414
# 1    0.440368  0.802368  0.966730  0.624770  1.046791  0.974442
# 2    0.440354  0.802346  0.966658  0.624729  1.046771  0.974458
# 3    0.440393  0.802405  0.966852  0.624839  1.046827  0.974414
# 4    0.440382  0.802388  0.966795  0.624807  1.046810  0.974427
# ..        ...       ...       ...       ...       ...       ...
# 191  0.392864  0.540894  0.431326  0.589509  0.842524  0.027345
# 192  0.482776  0.685900  0.893824  0.835198  0.978899 -0.018233
# 193  0.488682  0.696351  0.925662  0.850863  0.988520 -0.016361
# ...

# %%
n_train = 300
n_hidden_layer = [20, 20]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L2(
#   (hidden_layer1): Linear(in_features=2, out_features=20, bias=True)
#   (hidden_layer2): Linear(in_features=20, out_features=20, bias=True)
#   (predict_layer): Linear(in_features=20, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 69.87766
#             0         1         2         3         4         5
# 0    0.400370  0.761995  0.920782  0.803844  1.001889  1.008415
# 1    0.105831  1.084721  0.989215  0.850776  0.215030 -0.032081
# 2    0.401282  0.762188  0.922218  0.798872  1.007224  1.021082
# 3    0.400296  0.761980  0.920665  0.804251  1.001452  1.007378
# 4    0.400367  0.761995  0.920778  0.803860  1.001871  1.008373
# ..        ...       ...       ...       ...       ...       ...
# 191  0.495311  0.665229  0.873613  0.816684  0.992882  0.025640
# 192  0.431179  0.737437  0.825486  0.542336  1.005635  0.594154
# 193  0.396044  0.533169  0.168149  0.203006  0.967723  0.901336
# ...

# %%
n_train = 300
n_hidden_layer = [30, 30]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L2(
#   (hidden_layer1): Linear(in_features=2, out_features=30, bias=True)
#   (hidden_layer2): Linear(in_features=30, out_features=30, bias=True)
#   (predict_layer): Linear(in_features=30, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 77.53108
#             0         1         2         3         4         5
# 0    0.389220  0.804514  0.969347  0.639207  0.978803  0.972538
# 1    0.261155  0.755074  0.596528  0.635560  0.626697  0.627168
# 2    0.389648  0.807451  0.976246  0.642538  0.978298  0.972391
# 3    0.390732  0.814882  0.993700  0.650966  0.977022  0.972019
# 4    0.389687  0.807719  0.976875  0.642842  0.978252  0.972378
# ..        ...       ...       ...       ...       ...       ...
# 191  0.510901  0.665574  0.902838  0.823659  0.993063 -0.075462
# 192  0.510678  0.678442  0.929785  0.827733  0.996857 -0.040695
# 193  0.399491  0.737543  0.852599  0.573924  1.029311  0.963329
# ...

# %%
n_train = 300
n_hidden_layer = [10, 10, 10]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L3(
#   (hidden_layer1): Linear(in_features=2, out_features=10, bias=True)
#   (hidden_layer2): Linear(in_features=10, out_features=10, bias=True)
#   (hidden_layer3): Linear(in_features=10, out_features=10, bias=True)
#   (predict_layer): Linear(in_features=10, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 121.90534
#             0         1         2         3         4         5
# 0    0.430749  0.726377  0.935305  0.838320  0.996492  1.013051
# 1    0.430740  0.726367  0.935263  0.838269  0.996443  1.012933
# 2    0.431517  0.727230  0.938786  0.842525  1.000590  1.022811
# 3    0.430223  0.725793  0.932920  0.835439  0.993685  1.006366
# 4    0.430202  0.725770  0.932826  0.835325  0.993574  1.006102
# ..        ...       ...       ...       ...       ...       ...
# 191  0.439784  0.659742  0.756925  0.654783  0.963969  0.281686
# 192  0.439784  0.659742  0.756925  0.654783  0.963969  0.281686
# ...

# %%
n_train = 300
n_hidden_layer = [20, 20, 20]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L3(
#   (hidden_layer1): Linear(in_features=2, out_features=20, bias=True)
#   (hidden_layer2): Linear(in_features=20, out_features=20, bias=True)
#   (hidden_layer3): Linear(in_features=20, out_features=20, bias=True)
#   (predict_layer): Linear(in_features=20, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 124.40512
#             0         1         2         3         4         5
# 0    0.450139  0.754771  0.930595  0.816238  1.003625  0.989665
# 1    0.451354  0.752334  0.928838  0.815206  0.995917  0.985451
# 2    0.451647  0.751747  0.928414  0.814958  0.994058  0.984435
# 3    0.451293  0.752457  0.928927  0.815259  0.996307  0.985664
# 4    0.468410  0.685638  0.768616  0.684437  0.956610  0.257242
# ..        ...       ...       ...       ...       ...       ...
# 191  0.468410  0.685638  0.768616  0.684437  0.956610  0.257242
# 192  0.468410  0.685638  0.768616  0.684437  0.956610  0.257242
# ...

# %%
n_train = 300
n_hidden_layer = [30, 30, 30]
learning_rate = 0.1

AL.ANN_Linear_train_test(n_train, n_hidden_layer, learning_rate, backward = True)
# Out:
# ANN_L3(
#   (hidden_layer1): Linear(in_features=2, out_features=30, bias=True)
#   (hidden_layer2): Linear(in_features=30, out_features=30, bias=True)
#   (hidden_layer3): Linear(in_features=30, out_features=30, bias=True)
#   (predict_layer): Linear(in_features=30, out_features=6, bias=True)
# )
# The main square error of trained net in test set (expected and predicted): 95.50515
#             0         1         2         3         4         5
# 0    0.449265  0.787664  0.916307  0.821339  1.006400  0.980383
# 1    0.449490  0.787241  0.913486  0.818913  1.003216  0.978078
# 2    0.449465  0.787289  0.913806  0.819189  1.003577  0.978339
# 3    0.449331  0.787541  0.915487  0.820634  1.005474  0.979713
# 4    0.449472  0.787277  0.913722  0.819116  1.003483  0.978271
# ..        ...       ...       ...       ...       ...       ...
# 191  0.459165  0.500553  0.737809  0.849566  0.973977  0.035762
# 192  0.473974  0.504932  0.821462  0.881891  1.010144  0.026738
# ...
